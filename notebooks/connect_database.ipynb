# %%
import pandas as pd
import os 
from sqlalchemy import create_engine
import logging
import time


log_path = r"C:/Users/My computer & laptop/Desktop/Project # 2/logs/ingestion_db.log"

# Create folder if missing
os.makedirs(os.path.dirname(log_path), exist_ok=True)

logging.basicConfig(
    filename=log_path,
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

# %%
engine = create_engine(
    "mssql+pyodbc://@DESKTOP-5TNMJ27\SQLEXPRESS/vendor_analysis"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

# %%
def load_raw_data():
    start = time.time()
    for file in os.listdir('data'):
        if '.csv' in file:
            df = pd.read_csv('data/' + file)
            logging.info(df.shape)
            ingest_db(df,file[:-4],engine)
    logging.info('Ingestion Complete')
    end = time.time()
    Total_time = (start - end)/60
    logging.info(f'Total time taken{Total_time} minutes')

# %%
def ingest_db(df,table_name,engine):
    df.to_sql(table_name,con=engine, if_exists='replace',index=False)

# %%
from sqlalchemy import create_engine
engine = create_engine(
    "mssql+pyodbc://DESKTOP-5TNMJ27\\SQLEXPRESS/vendor_analysis"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)
table_name = "vendor_invoice"    # choose any table name
df = pd.read_csv(r'C:\Users\My computer & laptop\Desktop\Project # 2\data\vendor_invoice.csv')
df.to_sql(table_name, engine, if_exists="replace", index=False)
# Out:
# 109
